# %% [markdown]
# # Data Science Project : Apple iPhone Sales Analysis

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

# %%
data = pd.read_csv("apple_products.csv")

# %%
print(data.head())
print(data.columns)
# Out:
#                                Product Name  \
# 0         APPLE iPhone 8 Plus (Gold, 64 GB)
# 1  APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2      APPLE iPhone 8 Plus (Silver, 256 GB)
# 3           APPLE iPhone 8 (Silver, 256 GB)
# 4             APPLE iPhone 8 (Gold, 256 GB)
#
#                                          Product URL  Brand  Sale Price  \
# 0  https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3  https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# 4  https://www.flipkart.com/apple-iphone-8-gold-2...  Apple       77000
#
#      Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 0  49900                    0               3431                356
# 1  84900                    0               3431                356
# 2  84900                    0               3431                356
# 3  77000                    0              11202                794
# 4  77000                    0              11202                794
#
#                 Upc  Star Rating   Ram
# 0  MOBEXRGV7EHHTGUH          4.6  2 GB
# 1  MOBEXRGVAC6TJT4F          4.6  2 GB
# 2  MOBEXRGVGETABXWZ          4.6  2 GB
# 3  MOBEXRGVMZWUHCBA          4.5  2 GB
# 4  MOBEXRGVPK7PFEJZ          4.5  2 GB
# Index(['Product Name', 'Product URL', 'Brand', 'Sale Price', 'Mrp',
#        'Discount Percentage', 'Number Of Ratings', 'Number Of Reviews', 'Upc',
#        'Star Rating', 'Ram'],
#       dtype='object')

# %%
print(data.isnull().sum())
# Out:
# Product Name           0
# Product URL            0
# Brand                  0
# Sale Price             0
# Mrp                    0
# Discount Percentage    0
# Number Of Ratings      0
# Number Of Reviews      0
# Upc                    0
# Star Rating            0
# Ram                    0
# dtype: int64

# %%
data.describe()
# Out:
#           Sale Price            Mrp  Discount Percentage  Number Of Ratings  \
# count      62.000000      62.000000            62.000000          62.000000
# mean    80073.887097   88058.064516             9.951613       22420.403226
# std     34310.446132   34728.825597             7.608079       33768.589550
# min     29999.000000   39900.000000             0.000000         542.000000
# 25%     49900.000000   54900.000000             6.000000         740.000000
# 50%     75900.000000   79900.000000            10.000000        2101.000000
# 75%    117100.000000  120950.000000            14.000000       43470.000000
# max    140900.000000  149900.000000            29.000000       95909.000000
#
#        Number Of Reviews  Star Rating
# count          62.000000    62.000000
# mean         1861.677419     4.575806
# std          2855.883830     0.059190
# min            42.000000     4.500000
# 25%            64.000000     4.500000
# 50%           180.000000     4.600000
# 75%          3331.000000     4.600000
# max          8161.000000     4.700000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Sale Price'].plot(kind='hist', bins=20, title='Sale Price')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Mrp'].plot(kind='hist', bins=20, title='Mrp')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Discount Percentage'].plot(kind='hist', bins=20, title='Discount Percentage')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['Number Of Ratings'].plot(kind='hist', bins=20, title='Number Of Ratings')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='Sale Price', y='Mrp', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='Mrp', y='Discount Percentage', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='Discount Percentage', y='Number Of Ratings', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='Number Of Ratings', y='Number Of Reviews', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['Sale Price'].plot(kind='line', figsize=(8, 4), title='Sale Price')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['Mrp'].plot(kind='line', figsize=(8, 4), title='Mrp')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['Discount Percentage'].plot(kind='line', figsize=(8, 4), title='Discount Percentage')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['Number Of Ratings'].plot(kind='line', figsize=(8, 4), title='Number Of Ratings')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
highest_rated = data.sort_values(by=['Star Rating'], ascending=False)
highest_rated
# Out:
#                                         Product Name  \
# 15             APPLE iPhone 11 Pro Max (Gold, 64 GB)
# 20   APPLE iPhone 11 Pro Max (Midnight Green, 64 GB)
# 17       APPLE iPhone 11 Pro Max (Space Grey, 64 GB)
# 16  APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)
# 14            APPLE iPhone 11 Pro Max (Gold, 256 GB)
# ..                                               ...
# 52                    APPLE iPhone SE (White, 64 GB)
# 53                   APPLE iPhone SE (Black, 128 GB)
# 57                    APPLE iPhone SE (Black, 64 GB)
# 54                   APPLE iPhone SE (White, 128 GB)
# 55                     APPLE iPhone SE (Red, 128 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 15  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      117100
# 20  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      117100
# 17  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      117100
# 16  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      131900
# 14  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      131900
# ..                                                ...    ...         ...
# 52  https://www.flipkart.com/apple-iphone-se-white...  Apple       29999
# 53  https://www.flipkart.com/apple-iphone-se-black...  Apple       34999
# 57  https://www.flipkart.com/apple-iphone-se-black...  Apple       29999
# 54  https://www.flipkart.com/apple-iphone-se-white...  Apple       34999
# 55  https://www.flipkart.com/apple-iphone-se-red-1...  Apple       34999
#
#        Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 15  117100                    0               1078                101
# 20  117100                    0               1078                101
# 17  117100                    0               1078                101
# 16  131900                    0               1078                101
# 14  131900                    0               1078                101
# ..     ...                  ...                ...                ...
# 52   39900                   24              95807               8154
# 53   44900                   22              95909               8161
# 57   39900                   24              95909               8161
# 54   44900                   22              95807               8154
# 55   44900                   22              95909               8161
#
#                  Upc  Star Rating   Ram
# 15  MOBFKCTSAPAYNSGG          4.7  4 GB
# 20  MOBFKCTSRYPAQNYT          4.7  4 GB
# 17  MOBFKCTSKDMKCGQS          4.7  4 GB
# 16  MOBFKCTSCAAKGQV7          4.7  4 GB
# 14  MOBFKCTS7HCHSPFH          4.7  4 GB
# ..               ...          ...   ...
# 52  MOBFWQ6BGWDVGF3E          4.5  2 GB
# 53  MOBFWQ6BHUEVZPXD          4.5  2 GB
# 57  MOBFWQ6BR3MK7AUG          4.5  4 GB
# 54  MOBFWQ6BJEHMUUZY          4.5  2 GB
# 55  MOBFWQ6BJTVFKPEJ          4.5  2 GB
#
# [62 rows x 11 columns]

# %%
iphones = highest_rated["Product Name"].value_counts()
label = iphones.index
label
# Out:
# Index(['APPLE iPhone 11 Pro Max (Gold, 64 GB)',
#        'APPLE iPhone 11 Pro Max (Midnight Green, 64 GB)',
#        'APPLE iPhone 11 Pro Max (Space Grey, 64 GB)',
#        'APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)',
#        'APPLE iPhone 11 Pro Max (Gold, 256 GB)',
#        'APPLE iPhone 8 Plus (Gold, 64 GB)',
#        'Apple iPhone XR (Black, 128 GB) (Includes EarPods, Power Adapter)',
#        'Apple iPhone XR (Coral, 128 GB) (Includes EarPods, Power Adapter)',
#        'Apple iPhone XR ((PRODUCT)RED, 128 GB) (Includes EarPods, Power Adapter)',
#        'APPLE iPhone 8 Plus (Space Grey, 256 GB)',
#        'APPLE iPhone 8 Plus (Silver, 256 GB)',
#        'APPLE iPhone 8 Plus (Silver, 64 GB)',
#        'APPLE iPhone XS Max (Silver, 64 GB)',
#        'APPLE iPhone 8 Plus (Space Grey, 64 GB)',
#        'APPLE iPhone 11 Pro (Space Grey, 256 GB)',
#        'APPLE iPhone 12 Pro Max (Pacific Blue, 256 GB)',
#        'APPLE iPhone 12 (White, 128 GB)',
#        'Apple iPhone XR (White, 128 GB) (Includes EarPods, Power Adapter)',
#        'Apple iPhone XR (Black, 64 GB) (Includes EarPods, Power Adapter)',
#        'APPLE iPhone 11 Pro (Midnight Green, 64 GB)',
#        'APPLE iPhone 11 Pro (Space Grey, 512 GB)',
#        'APPLE iPhone 11 Pro (Midnight Green, 512 GB)',
#        'APPLE iPhone 12 Pro Max (Gold, 128 GB)',
#        'APPLE iPhone 12 (Green, 128 GB)', 'APPLE iPhone 12 (Black, 64 GB)',
#        'APPLE iPhone 12 Pro Max (Silver, 128 GB)',
#        'APPLE iPhone 12 (Black, 128 GB)', 'APPLE iPhone 12 (Blue, 128 GB)',
#        'APPLE iPhone 12 Pro Max (Graphite, 128 GB)',
#        'APPLE iPhone 12 Pro Max (Graphite, 256 GB)',
#        'APPLE iPhone 11 (Red, 64 GB)', 'APPLE iPhone 11 (Purple, 64 GB)',
#        'APPLE iPhone 11 (Black, 64 GB)', 'APPLE iPhone 11 (Black, 128 GB)',
#        'APPLE iPhone 11 (White, 128 GB)',
#        'APPLE iPhone 12 Pro Max (Gold, 256 GB)',
#        'APPLE iPhone 12 Pro Max (Silver, 256 GB)',
#        'APPLE iPhone 12 Pro Max (Pacific Blue, 128 GB)',
#        'APPLE iPhone 12 (Red, 128 GB)', 'APPLE iPhone 12 (White, 64 GB)',
#        'APPLE iPhone 11 (White, 64 GB)', 'APPLE iPhone 11 (Red, 128 GB)',
#        'Apple iPhone SE (White, 256 GB) (Includes EarPods, Power Adapter)',
#        'APPLE iPhone 8 (Silver, 256 GB)', 'APPLE iPhone 8 (Gold, 256 GB)',
#        'APPLE iPhone 8 (Space Grey, 256 GB)',
#        'APPLE iPhone 12 Mini (White, 64 GB)',
#        'APPLE iPhone 12 Pro (Graphite, 256 GB)',
#        'APPLE iPhone 12 Mini (White, 128 GB)',
#        'APPLE iPhone 12 Pro (Silver, 512 GB)',
#        'APPLE iPhone 12 Mini (Black, 128 GB)',
#        'APPLE iPhone 12 Pro (Graphite, 128 GB)',
#        'APPLE iPhone 12 Mini (Red, 64 GB)',
#        'APPLE iPhone 12 Mini (Blue, 128 GB)',
#        'APPLE iPhone 12 Mini (Black, 64 GB)',
#        'APPLE iPhone 12 Pro (Pacific Blue, 512 GB)',
#        'APPLE iPhone 12 Pro (Pacific Blue, 128 GB)',
#        'APPLE iPhone SE (White, 64 GB)', 'APPLE iPhone SE (Black, 128 GB)',
#        'APPLE iPhone SE (Black, 64 GB)', 'APPLE iPhone SE (White, 128 GB)',
#        'APPLE iPhone SE (Red, 128 GB)'],
#       dtype='object', name='Product Name')

# %%
counts = highest_rated["Number Of Ratings"]
figure = px.bar(highest_rated, x=label, y=counts, title="Number of Ratings of Different Iphones")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="
ue, 512 GB)","APPLE iPhone 12 Pro (Pacific Blue, 128 GB)","APPLE iPhone SE (White, 64 GB)","APPLE iPhone SE (Black, 128 GB)","APPLE iPhone SE (Black, 64 GB)","APPLE iPhone SE (White, 128 GB)","APPLE iPhone SE (Red, 128 GB)"],"xaxis":"x","y":[1078,1078,1078,1078,1078,3431,79512,79582,79512,3431,3431,3431,1454,3431,7081,580,2101,79512,79512,7088,7088,7088,580,2092,2092,580,2101,2101,580,580,43470,43470,43470,43470,43707,580,580,580,2101,2101,43470,43707,95909,11202,11202,11202,740,545,740,542,730,545,740,730,740,545,545,95807,95909,95909,95807,95909],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22222 ...

# %%
iphones = highest_rated["Product Name"].value_counts()
label = iphones.index
counts = highest_rated["Number Of Reviews"]
figure = px.bar(highest_rated, x=label, y=counts, title="Number of Reviews of Different Iphones")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="74378f76-a779-41cb-9b2f-80211407fd21" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74378f76-a779-41cb-9b2f-80211407fd21")) {                    Plotly.newPlot(                        "74378f76-a779-41cb-9b2f-80211407fd21",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}\u003cbr\u003eNumber Of Reviews=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["APPLE iPhone 11 Pro Max (Gold, 64 GB)","APPLE iPhone 11 Pro Max (Midnight Green, 64 GB)","APPLE iPhone 11 Pro Max (Space Grey, 64 GB)","APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)","APPLE iPhone 11 Pro Max (Gold, 256 GB)","APPLE iPhone 8 Plus (Gold, 64 GB)","Apple iPhone XR (Black, 128 GB) (Includes EarPods, Power Adapter)","Apple iPhone XR (Coral, 128 GB) (Includes EarPods, Power Adapter)","Apple iPhone XR ((PRODUCT)RED, 128 GB) (Includes EarPods, Power Adapter)","APPLE iPhone 8 Plus (Space Grey, 256 GB)","APPLE iPhone 8 Plus (Silver, 256 GB)","APPLE iPhone 8 Plus (Silver, 64 GB)","APPLE iPhone XS Max (Silver, 64 GB)","APPLE iPhone 8 Plus (Space Grey, 64 GB)","APPLE iPhone 11 Pro (Space Grey, 256 GB)","APPLE iPhone 12 Pro Max (Pacific Blue, 256 GB)","APPLE iPhone 12 (White, 128 GB)","Apple iPhone XR (White, 128 GB) (Includes EarPods, Power Adapter)","Apple iPhone XR (Black, 64 GB) (Includes EarPods, Power Adapter)","APPLE iPhone 11 Pro (Midnight Green, 64 GB)","APPLE iPhone 11 Pro (Space Grey, 512 GB)","APPLE iPhone 11 Pro (Midnight Green, 512 GB)","APPLE iPhone 12 Pro Max (Gold, 128 GB)","APPLE iPhone 12 (Green, 128 GB)","APPLE iPhone 12 (Black, 64 GB)","APPLE iPhone 12 Pro Max (Silver, 128 GB)","APPLE iPhone 12 (Black, 128 GB)","APPLE iPhone 12 (Blue, 128 GB)","APPLE iPhone 12 Pro Max (Graphite, 128 GB)","APPLE iPhone 12 Pro Max (Graphite, 256 GB)","APPLE iPhone 11 (Red, 64 GB)","APPLE iPhone 11 (Purple, 64 GB)","APPLE iPhone 11 (Black, 64 GB)","APPLE iPhone 11 (Black, 128 GB)","APPLE iPhone 11 (White, 128 GB)","APPLE iPhone 12 Pro Max (Gold, 256 GB)","APPLE iPhone 12 Pro Max (Silver, 256 GB)","APPLE iPhone 12 Pro Max (Pacific Blue, 128 GB)","APPLE iPhone 12 (Red, 128 GB)","APPLE iPhone 12 (White, 64 GB)","APPLE iPhone 11 (White, 64 GB)","APPLE iPhone 11 (Red, 128 GB)","Apple iPhone SE (White, 256 GB) (Includes EarPods, Power Adapter)","APPLE iPhone 8 (Silver, 256 GB)","APPLE iPhone 8 (Gold, 256 GB)","APPLE iPhone 8 (Space Grey, 256 GB)","APPLE iPhone 12 Mini (White, 64 GB)","APPLE iPhone 12 Pro (Graphite, 256 GB)","APPLE iPhone 12 Mini (White, 128 GB)","APPLE iPhone 12 Pro (Silver, 512 GB)","APPLE iPhone 12 Mini (Black, 128 GB)","APPLE iPhone 12 Pro (Graphite, 128 GB)","APPLE iPhone 12 Mini (Red, 64 GB)","APPLE iPhone 12 Mini (Blue, 128 GB)","APPLE iPhone 12 Mini (Black, 64 GB)","APPLE iPhone 12 Pro (Pacific Blue, 512 GB)","APPLE iPhone 12 Pro (Pacific Blue, 128 GB)","APPLE iPhone SE (White, 64 GB)","APPLE iPhone SE (Black, 128 GB)","APPLE iPhone SE (Black, 64 GB)","APPLE iPhone SE (White, 128 GB)","APPLE iPhone SE (Red, 128 GB)"],"xaxis":"x","y":[101,101,101,101,101,356,6796,6804,6796,356,356,356,149,356,522,45,180,6796,6796,523,523,523,45,178,178,45,180,180,45,45,3331,3331,3331,3331,3357,45,45,45,180,180,3331,3357,8161,794,794,794,64,42,64,42,63,42,64,63,64,42,42,8154,8161,8161,8154,8161],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444444 ...

# %%
figure = px.scatter(data_frame = data, x='Number Of Ratings', y='Sale Price', size='Discount Percentage', title="Relationship between Sale Price, Number of Ratings and Discount Percentage")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5c292c93-9f97-44b2-9235-d3d293ac3f19" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5c292c93-9f97-44b2-9235-d3d293ac3f19")) {                    Plotly.newPlot(                        "5c292c93-9f97-44b2-9235-d3d293ac3f19",                        [{"hovertemplate":"Number Of Ratings=%{x}\u003cbr\u003eSale Price=%{y}\u003cbr\u003eDiscount Percentage=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","size":[0,0,0,0,0,0,0,0,0,20,16,20,20,20,0,0,0,0,29,15,0,15,17,18,6,6,13,6,14,10,7,6,6,13,13,10,10,6,14,6,10,6,11,11,10,14,7,6,6,6,8,8,24,22,22,22,8,24,14,14,14,14],"sizemode":"area","sizeref":0.0725,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[3431,3431,3431,11202,11202,3431,3431,11202,1454,79512,79512,79582,79512,79512,1078,1078,1078,1078,7088,7088,1078,7088,7081,95909,542,580,740,545,740,2101,545,580,580,730,730,2101,2101,580,740,580,2092,545,2101,2092,2101,740,545,580,580,580,43707,43707,95807,95909,95807,95909,43470,95909,43470,43470,43470,43470],"xaxis":"x","y":[49900,84900,84900,77000,77000,49900,49900,77000,89900,41999,39999,41999,41999,41999,131900,117100,131900,117100,74999,117900,117100,117900,99900,44999,140900,130900,64900,120900,59900,75900,110900,130900,120900,64900,64900,75900,75900,120900,59900,120900,75900,140900,70900,70900,75900,59900,110900,120900,130900,130900,54999,54999,29999,34999,34999,34999,54999,29999,46999,46999,46999,46999],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.11111111111 ...

# %%
figure = px.scatter(
    data_frame=data,
    x="Number Of Ratings",
    y="Discount Percentage",
    size="Sale Price",
    trendline="ols",
    title="Relationship between Discount Percentage and Number Of Ratings"
)

figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5f97eb95-4a53-4ae1-bf68-4ccd20b9ac44" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5
# Number Of Ratings                                                    542
# Number Of Reviews                                                     42
# Upc                                                     MOBFWBYZ5UY6ZBVA
# Star Rating                                                          4.5
# Ram                                                                 4 GB
# Name: 24, dtype: object
#
# Least Expensive Product:
# Product Name                              APPLE iPhone SE (White, 64 GB)
# Product URL            https://www.flipkart.com/apple-iphone-se-white...
# Brand                                                              Apple
# Sale Price                                                         29999
# Mrp                                                                39900
# Discount Percentage                                                   24
# Number Of Ratings                                                  95807
# Number Of Reviews                                                   8154
# Upc                                                     MOBFWQ6BGWDVGF3E
# Star Rating                                                          4.5
# Ram                                                                 2 GB
# Name: 52, dtype: object

# %% [markdown]
# # Additional features

# %% [markdown]
# ## Analyze Discount Percentage
#
# ### Subtask:
# Calculate and display the average discount percentage across all products.

# %% [markdown]
# **Reasoning**:
# To calculate the average discount percentage, I need to get the mean of the 'Discount Percentage' column from the 'data' DataFrame.

# %%
average_discount = data['Discount Percentage'].mean()
print(f"Average Discount Percentage: {average_discount:.2f}%")
# Out:
# Average Discount Percentage: 9.95%

# %% [markdown]
# ## Identify Most Rated Products
#
# ### Subtask:
# Identify and display the top 10 iPhones based on the 'Number Of Ratings'.

# %% [markdown]
# **Reasoning**:
# To identify the top 10 iPhones by 'Number Of Ratings', I will first sort the 'data' DataFrame by this column in descending order, then select the top 10 products and display their names and number of ratings.

# %%
top_10_rated = data.sort_values(by='Number Of Ratings', ascending=False).head(10)
print("Top 10 iPhones by Number Of Ratings:")
print(top_10_rated[['Product Name', 'Number Of Ratings']])
# Out:
# Top 10 iPhones by Number Of Ratings:
#                                          Product Name  Number Of Ratings
# 23  Apple iPhone SE (White, 256 GB) (Includes EarP...              95909
# 55                      APPLE iPhone SE (Red, 128 GB)              95909
# 57                     APPLE iPhone SE (Black, 64 GB)              95909
# 53                    APPLE iPhone SE (Black, 128 GB)              95909
# 52                     APPLE iPhone SE (White, 64 GB)              95807
# 54                    APPLE iPhone SE (White, 128 GB)              95807
# 11  Apple iPhone XR (Coral, 128 GB) (Includes EarP...              79582
# 12  Apple iPhone XR (Black, 128 GB) (Includes EarP...              79512
# 13  Apple iPhone XR (White, 128 GB) (Includes EarP...              79512
# 10  Apple iPhone XR (Black, 64 GB) (Includes EarPo...              79512

# %% [markdown]
# ## Identify Most Reviewed Products
#
# ### Subtask:
# Identify and display the top 10 iPhones based on the 'Number Of Reviews'.

# %% [markdown]
# **Reasoning**:
# To identify the top 10 iPhones by 'Number Of Reviews', I will first sort the 'data' DataFrame by this column in descending order, then select the top 10 products and display their names and number of reviews.

# %% [markdown]
# **Reasoning**:
# To identify the top 10 iPhones by 'Number Of Reviews', I will sort the DataFrame, select the top 10 rows, and display the product name and number of reviews.

# %%
top_10_reviewed = data.sort_values(by='Number Of Reviews', ascending=False).head(10)
print("Top 10 iPhones by Number Of Reviews:")
print(top_10_reviewed[['Product Name', 'Number Of Reviews']])
# Out:
# Top 10 iPhones by Number Of Reviews:
#                                          Product Name  Number Of Reviews
# 23  Apple iPhone SE (White, 256 GB) (Includes EarP...               8161
# 55                      APPLE iPhone SE (Red, 128 GB)               8161
# 57                     APPLE iPhone SE (Black, 64 GB)               8161
# 53                    APPLE iPhone SE (Black, 128 GB)               8161
# 52                     APPLE iPhone SE (White, 64 GB)               8154
# 54                    APPLE iPhone SE (White, 128 GB)               8154
# 11  Apple iPhone XR (Coral, 128 GB) (Includes EarP...               6804
# 12  Apple iPhone XR (Black, 128 GB) (Includes EarP...               6796
# 13  Apple iPhone XR (White, 128 GB) (Includes EarP...               6796
# 10  Apple iPhone XR (Black, 64 GB) (Includes EarPo...               6796

# %% [markdown]
# ## Visualize Star Rating Distribution
#
# ### Subtask:
# Generate a histogram or bar chart to visualize the distribution of 'Star Rating' across all products. This will show the general sentiment of the ratings.

# %% [markdown]
# **Reasoning**:
# To visualize the distribution of 'Star Rating', I will use `plotly.express.histogram` on the 'Star Rating' column of the `data` DataFrame and set the appropriate title.

# %%
figure = px.histogram(data, x='Star Rating', title='Distribution of Star Ratings')
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="712f6034-e832-4be3-a34d-d6d2152c0f47" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("712f6034-e832-4be3-a34d-d6d2152c0f47")) {                    Plotly.newPlot(                        "712f6034-e832-4be3-a34d-d6d2152c0f47",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Star Rating=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[4.6,4.6,4.6,4.5,4.5,4.6,4.6,4.5,4.6,4.6,4.6,4.6,4.6,4.6,4.7,4.7,4.7,4.7,4.6,4.6,4.7,4.6,4.6,4.5,4.5,4.6,4.5,4.5,4.5,4.6,4.5,4.6,4.6,4.5,4.5,4.6,4.6,4.6,4.5,4.6,4.6,4.5,4.6,4.6,4.6,4.5,4.5,4.6,4.6,4.6,4.6,4.6,4.5,4.5,4.5,4.5,4.6,4.5,4.6,4.6,4.6,4.6],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker": ...

# %% [markdown]
# ## Visualize Sale Price Distribution
#
# ### Subtask:
# Generate a histogram to visualize the distribution of 'Sale Price'.

# %% [markdown]
# **Reasoning**:
# To visualize the distribution of 'Sale Price', I will use `plotly.express.histogram` on the 'Sale Price' column of the `data` DataFrame and add a descriptive title.

# %%
figure = px.histogram(data, x='Sale Price', title='Distribution of Sale Price')
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="09f87821-0625-45a7-b7af-a01b775c886c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("09f87821-0625-45a7-b7af-a01b775c886c")) {                    Plotly.newPlot(                        "09f87821-0625-45a7-b7af-a01b775c886c",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Sale Price=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[49900,84900,84900,77000,77000,49900,49900,77000,89900,41999,39999,41999,41999,41999,131900,117100,131900,117100,74999,117900,117100,117900,99900,44999,140900,130900,64900,120900,59900,75900,110900,130900,120900,64900,64900,75900,75900,120900,59900,120900,75900,140900,70900,70900,75900,59900,110900,120900,130900,130900,54999,54999,29999,34999,34999,34999,54999,29999,46999,46999,46999,46999],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scat ...

# %% [markdown]
# ## Final Task

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The average discount percentage across all analyzed Apple products is approximately 9.95%.
# *   The top 10 iPhones by 'Number Of Ratings' are primarily dominated by various models of the Apple iPhone SE (e.g., Apple iPhone SE (White, 256 GB), APPLE iPhone SE (Red, 128 GB)) and Apple iPhone XR, with rating counts around 95,909 for SE models and 79,500 for XR models.
# *   Similarly, the top 10 iPhones by 'Number Of Reviews' largely consist of Apple iPhone SE (256GB, 128GB, and 64GB variants) and Apple iPhone XR (128GB and 64GB) models, with review counts ranging from 6,796 to 8,161.
# *   The distribution of 'Star Rating' was successfully visualized using a histogram, providing an overview of customer sentiment.
# *   The distribution of 'Sale Price' was successfully visualized using a histogram, illustrating the price ranges of the products.
